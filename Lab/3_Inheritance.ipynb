# %%
#this is the function for the person who is travelling in the flight
class individual():
  #intialising the details of the traveller of the 
    def __init__(self, indName, indEmail, indPhone):
        self.indName = indName
        self.indEmail = indEmail
        self.indPhone = indPhone       
    def getindName(self):
        print("Individual's-name:", self.indName)
    def getindPhone(self):
        print("Individual's-mobile: " + self.indPhone)
    def getindEmail(self):
        print("Individual's-mailID:", self.indEmail)

#Here we are building a function for the 
class F_Information():
    def __init__(self, Fnum, Fname):
        self.Fnum = Fnum
        self.Fname = Fname      
    def getFname(self):
        print("Airline_Company:", self.Fname)
    def getFnum(self):
        print("Flightt-Number:", self.Fnum)

#This particular function is build for the current booking details
class CurrntBuking(F_Information):
    def __init__(self, FlightSource, flightDestin, Flightdepturdate,flight_number,flight_name):
        F_Information.__init__(self, flight_number, flight_name)
        self.FlightSource = FlightSource
        self.flightDestin = flightDestin
        self.Flightdepturdate = Flightdepturdate
        self.flightname = flight_name
        self.flightnumber = flight_number       
    def getsource(self):
        print("Flight-Sourc :", self.FlightSource)
    def getdestination(self):
        print("Flight-Destin :", self.flightDestin)
    def getdeptdate(self):
        print("Flight_Departure:", self.Flightdepturdate)

#this function is inheriting all the details of the passenger and his booking status
class traveller(individual,CurrntBuking):
    def __init__(self, name, maiID, mob, flight_number,
                 flight_name, deptdate, source, destination):
        super().__init__(name, maiID, mob)
        CurrntBuking.__init__(self, deptdate, source, destination, flight_number, flight_name)   
        F_Information.__init__(self, flight_number, flight_name)
trav = traveller("Divya", "bandariDivya@gmail.com","9848022338", "APJ9871", "SpiceJet Airways", "MI", "WI", "jun 20")
print("The complete details of the individal with his current booking and his flight details:")
trav.getindName()
trav.getindEmail()
trav.getindPhone()
trav.getFname()
trav.getFnum()
trav.getsource()
trav.getdestination()
trav.getdeptdate()
# Out:
# The complete details of the individal with his current booking and his flight details:
# Individual's-name: Divya
# Individual's-mailID: bandariDivya@gmail.com
# Individual's-mobile: 9848022338
# Airline_Company: SpiceJet Airways
# Flightt-Number: APJ9871
# Flight-Sourc : MI
# Flight-Destin : WI
# Flight_Departure: jun 20
